# %% [markdown]
# # Setup (always run this!)

# %%
# importing modules
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
from pathlib import Path
import fiona
import gdal
import json

# setting up directories
data_dir = Path('data/')
lang_dir = data_dir / 'language_data'
gis_dir = data_dir / 'boundaries'

# function to reformat .json and .geojson files
# essentially improves readability of file content
def reformat_json(json_file: Path):
    if not json_file.exists():
        raise FileNotFoundError(f'Unable to find file {json_file}')
    with open(json_file) as f:
        data = json.load(f)
    with open(json_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=True, indent=4)

# %% [markdown]
# # Preprocessing for "graficos_immigracion_por_nacionalidad"

# %% [markdown]
# Loading and preprocessing immigration data

# %%
file_immigration = lang_dir / 'Karte1_inmigración_total_nacionalidad.xlsx'

df_immigration = pd.read_excel(file_immigration, sheet_name='Einwanderung_new')

df_immigration = df_immigration.rename(columns={'Nacionalidad': 'name'})

# used to retrieve flags from https://flag-icon-css.lip.is/
countryIDs = {
    'Argentinien': 'ar',
    'Bolivien': 'bo',
    'Chile': 'cl',
    'Colombia': 'co',
    'Costa Rica': 'cr',
    'Dominikanische Republik': 'do',
    'Ecuador': 'ec',
    'El Salvador': 'sv',
    'Guatemala': 'gt',
    'Honduras': 'hn',
    'Kolumbien': 'co',
    'Kuba': 'cu',
    'Mexiko': 'mx',
    'Nicaragua': 'ni',
    'Panama': 'pa',
    'Paraguay': 'py',
    'Peru': 'pe',
    'Spanien': 'es',
    'Uruguay': 'uy',
    'Venezuela': 've',  
};

# adding geometry column
df_immigration['code'] = df_immigration.apply(lambda row: countryIDs[row['name']], axis=1)


# setting primary key to country name
df_immigration = df_immigration.set_index('name')

df_immigration.head()
# Out:
#                          1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# name
# Argentinien               357   270   247   195   195   175   167   180   171
# Bolivien                   95    79    80    76    86    81    71    91    97
# Chile                     487   379   272   238   202   190   186   167   219
# Costa Rica                 34    28    37    44    27    35    45    36    40
# Dominikanische Republik   275   555   694   659   741   631   562   565   511
#
#                          2000  ...  2010  2011  2012  2013  2014  2015  2016  \
# name                           ...
# Argentinien               210  ...   252   280   249   252   217   270   201
# Bolivien                   89  ...   252   185   148   135   117   134   156
# Chile                     240  ...   255   183   171   199   190   184   199
# Costa Rica                 28  ...    84    74    67    53    57    81    90
# Dominikanische Republik   548  ...   416   392   392   447   336   393   341
#
#                          2017  2018  code
# name
# Argentinien               207   241    ar
# Bolivien                  167   167    bo
# Chile                     178   229    cl
# Costa Rica                 75    90    cr
# Dominikanische Republik   325   281    do
#
# [5 rows x 29 columns]

# %% [markdown]
# Exporting as json file

# %%
save_dir = Path('graficos_immigracion_por_nacionalidad/')
output_file = save_dir / 'preprocessed_data.json'
df_immigration.to_json(output_file, orient='table')

# optional reformatting data
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_poblacion_por_nacionalidad"

# %% [markdown]
# Loading and preprocessing municipality data

# %%
# functions that returns a preprocessed data frame for an input year
def preprocess_stats_map2(year):
    
    file_municipality_stats = lang_dir / 'Karte2_población_nacionalidad.xlsx'
    
    df_municipality_stats = pd.read_excel(file_municipality_stats, sheet_name=f'{year}_new')

    # removing all non-municipality rows

    # function to determine whether a row is a municipality or not
    def is_municipality(row):
        place_name = row['Ortschaft']
        name_start = place_name.split()[0]

        # cantons start with -
        if name_start == '-':
            return False
        # districts start with >>
        elif name_start == '>>':
            return False
        else:
            return True

    df_municipality_stats['is_municipality'] = df_municipality_stats.apply(is_municipality,axis=1)    
    dropIndices = df_municipality_stats[df_municipality_stats['is_municipality'] == False].index
    df_municipality_stats = df_municipality_stats.drop(dropIndices)


    # adding bfs number column and municipality name column

    def split_column(row):
        place_name = row['Ortschaft']

        # splitting at first space
        bfs_number, name = place_name.split(' ', 1)
        bfs_number = int(bfs_number[-4:])

        return pd.Series({'bfs_number':bfs_number, 'name_old':name})

    new_columns = df_municipality_stats.apply(split_column, axis=1)                     
    df_municipality_stats = df_municipality_stats.merge(new_columns, left_index=True, right_index=True)                

    # put name column first
    df_municipality_stats.insert(0, 'name', df_municipality_stats.name_old)


    # removing Ortschaft column and is municipality column
    df_municipality_stats = df_municipality_stats.drop(labels=['Ortschaft', 'is_municipality', 'name_old'], axis=1)


    # setting primary key to bfs number
    df_municipality_stats = df_municipality_stats.set_index('bfs_number')


    # adding Total count
    countries = list(df_municipality_stats.columns)[1:]
    def sum_countries(row):
        total = 0
        for country in countries:
            total += row[country]
        return total

    df_municipality_stats['Total'] = df_municipality_stats.apply(sum_countries, axis=1)
    
    # renaming country counts according to year
    old_names = countries + ['Total']
    new_names = [f'{old_name}_{year}' for old_name in old_names]
    
    df_municipality_stats = df_municipality_stats.rename(columns=dict(zip(old_names, new_names)))
    
    return df_municipality_stats
    # end of the preprocessing function


    
startYear, endYear = 2010, 2018

df_municipality_stats = preprocess_stats_map2(startYear)

for year in range(startYear+1, endYear+1):
    df_year = preprocess_stats_map2(year)    
    df_year = df_year.drop(columns='name')
    df_municipality_stats = df_municipality_stats.join(df_year, how='inner', lsuffix='', rsuffix='')


df_municipality_stats.head()
# Out:
#                           name  Spanien_2010  Argentinien_2010  Bolivien_2010  \
# bfs_number
# 1              Aeugst am Albis             4                 1              0
# 2           Affoltern am Albis            39                 2              3
# 3                   Bonstetten            12                 2              0
# 4              Hausen am Albis             3                 0              0
# 5                     Hedingen            11                 3              0
#
#             Costa Rica_2010  Dominikanische Republik_2010  Ecuador_2010  \
# bfs_number
# 1                         0                             0             0
# 2                         0                            12             2
# 3                         0                             2             0
# 4                         0                             0             0
# 5                         0                             0             0
#
#             El Salvador_2010  Guatemala_2010  Honduras_2010  ...  \
# bfs_number                                                   ...
# 1                          0               0              0  ...
# 2                          0               0              0  ...
# 3                          0               0              0  ...
# 4                          0               0              0  ...
# 5                          0               0              0  ...
#
#             Kolumbien_2018  Kuba_2018  Mexiko_2018  Nicaragua_2018  \
# bfs_number
# 1                        1          0            1               0
# 2                        9          2            3               0
# 3                        0          0            1               0
# 4                        0          0            1               0
# 5                        2          0            1               0
#
#             Panama_2018  Paraguay_2018  Peru_2018  Uruguay_2018  \
# bfs_number
# 1                     0              0          0             0
# 2                     0              1          1             0
# 3                     0              0          1             0
# 4                     0              0          1             0
# 5                     0              0          0             0
#
#             Venezuela_2018  Total_2018
# bfs_number
# 1                        0          15
# 2                        0         101
# 3                        0          19
# 4                        5          13
# 5                        1          32
#
# [5 rows x 172 columns]

# %% [markdown]
# Loading and preprocessing municipalities polygons

# %%
file_municipalities = gis_dir / 'swissBOUNDARIES3D_1_3_TLM_HOHEITSGEBIET.shp'

gdf_municipalities = gpd.read_file(file_municipalities)

# change crs to wg84
gdf_municipalities = gdf_municipalities.to_crs({'init' :'epsg:4326'})

# subset to Switzerland
gdf_municipalities = gdf_municipalities[gdf_municipalities['ICC']=='CH']

# subset to municipalities (Kantonsgebiet is removed)
gdf_municipalities = gdf_municipalities[gdf_municipalities['OBJEKTART']=='Gemeindegebiet']


gdf_municipalities = gdf_municipalities[['BFS_NUMMER', 'NAME', 'EINWOHNERZ', 'GEM_FLAECH', 'KANTONSNUM', 'geometry']]

rename_dict = {
    'BFS_NUMMER': 'bfs_number',
    'NAME': 'name',
    'EINWOHNERZ': 'n_inhabitants',
    'GEM_FLAECH': 'area',
    'KANTONSNUM': 'canton_number'
}

gdf_municipalities = gdf_municipalities.rename(columns=rename_dict)

# setting primary key to bfs number
gdf_municipalities = gdf_municipalities.set_index('bfs_number')

print(gdf_municipalities.shape)

gdf_municipalities.head()
# Out:
# (2307, 5)
#                   name  n_inhabitants     area  canton_number  \
# bfs_number
# 3762             Scuol         4598.0  43861.0           18.0
# 1631        Glarus Süd         9581.0  43003.0            8.0
# 3746            Zernez         1532.0  34404.0           18.0
# 3543            Surses         2343.0  32377.0           18.0
# 6031            Bagnes         8100.0  28410.0           23.0
#
#                                                      geometry
# bfs_number
# 3762        POLYGON Z ((10.42272 46.78824 2898.19782, 10.4...
# 1631        POLYGON Z ((8.93538 46.91985 2655.04194, 8.935...
# 3746        POLYGON Z ((10.09693 46.84879 3253.89244, 10.0...
# 3543        POLYGON Z ((9.51989 46.49394 3100.30426, 9.520...
# 6031        POLYGON Z ((7.19637 46.11405 2387.52838, 7.197...

# %% [markdown]
# Join municipality stats with boundaries

# %%
gdf_municipalities = gdf_municipalities.join(df_municipality_stats, how='left', lsuffix='_left', rsuffix='_right')
gdf_municipalities = gdf_municipalities.rename(columns={'name_left': 'name'})
gdf_municipalities = gdf_municipalities.drop(['name_right'], axis=1)

print(gdf_municipalities.shape)

gdf_municipalities.head()
# Out:
# (2307, 176)
#                           name  n_inhabitants    area  canton_number  \
# bfs_number
# 1              Aeugst am Albis         1941.0   791.0            1.0
# 2           Affoltern am Albis        12146.0  1059.0            1.0
# 3                   Bonstetten         5512.0   743.0            1.0
# 4              Hausen am Albis         3664.0  1360.0            1.0
# 5                     Hedingen         3694.0   653.0            1.0
#
#                                                      geometry  Spanien_2010  \
# bfs_number
# 1           POLYGON Z ((8.50216 47.26132 700.56696, 8.5020...           4.0
# 2           POLYGON Z ((8.42614 47.27914 558.98992, 8.4259...          39.0
# 3           POLYGON Z ((8.48377 47.32378 676.24380, 8.4838...          12.0
# 4           POLYGON Z ((8.57437 47.21707 593.54844, 8.5743...           3.0
# 5           POLYGON Z ((8.47675 47.29307 791.40911, 8.4766...          11.0
#
#             Argentinien_2010  Bolivien_2010  Costa Rica_2010  \
# bfs_number
# 1                        1.0            0.0              0.0
# 2                        2.0            3.0              0.0
# 3                        2.0            0.0              0.0
# 4                        0.0            0.0              0.0
# 5                        3.0            0.0              0.0
#
#             Dominikanische Republik_2010  ...  Kolumbien_2018  Kuba_2018  \
# bfs_number                                ...
# 1                                    0.0  ...             1.0        0.0
# 2                                   12.0  ...             9.0        2.0
# 3                                    2.0  ...             0.0        0.0
# 4                                    0.0  ...             0.0        0.0
# 5                                    0.0  ...             2.0        0.0
#
#             Mexiko_2018  Nicaragua_2018  Panama_2018  Paraguay_2018  \
# bfs_number
# 1                   1.0             0.0          0.0            0.0
# 2                   3.0             0.0          0.0            1.0
# 3                   1.0             0.0          0.0            0.0
# 4                   1.0             0.0          0.0            0.0
# 5                   1.0             0.0          0.0            0.0
#
#             Peru_2018  Uruguay_2018  Venezuela_2018  Total_2018
# bfs_number
# 1                 0.0           0.0             0.0        15.0
# 2                 1.0           0.0             0.0       101.0
# 3                 1.0           0.0             0.0        19.0
# 4                 1.0           0.0             5.0        13.0
# 5                 0.0           0.0             1.0        32.0
#
# [5 rows x 176 columns]

# %% [markdown]
# Export as geojson

# %%
# export as geojson
# gdf_municipalities.to_file(f'../map2/map2.geojson', driver='GeoJSON', encoding='utf-8')

df_municipalities = pd.DataFrame(gdf_municipalities)
df_municipalities = df_municipalities.drop(columns=['geometry'])
# df_municipalities = df_municipalities.head(10)

df_municipalities = df_municipalities.reset_index()

print(df_municipalities.shape)
# Out:
# (2307, 176)

# %%
save_dir = Path('mapas_poblacion_por_nacionalidad')
output_file = save_dir / 'preprocessed_data.json'
df_municipalities.to_json(output_file, orient='columns')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_universidades"

# %% [markdown]
# Loading and preprocessing all bildung points

# %%
file_bildung = lang_dir / 'Masterlist_Bildung_Anzahlen.xlsx'

df_bildung = pd.read_excel(file_bildung)
df_bildung['geometry'] = df_bildung.apply(lambda x: Point(x['y'],x['x']), axis=1)
gdf_bildung = gpd.GeoDataFrame(df_bildung, geometry='geometry')


# setting primary key

gdf_unis = gdf_bildung[gdf_bildung['Typ'] == 'Universidad']
gdf_unis['name'] = gdf_unis['Name']
gdf_unis = gdf_unis.set_index('Name')
# print(gdf_unis.shape)

gdf_unis.head(100)
# Out:
# <ipython-input-7-de7cba2402da>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_unis['name'] = gdf_unis['Name']
#                                                    ID          Typ          x  \
# Name
# Universität Basel                                 NaN  Universidad  47.558234
# Universität Bern                                  NaN  Universidad  46.950078
# Université de Neuchâtel                           NaN  Universidad  46.993852
# Universität Fribourg                              NaN  Universidad  46.806263
# Universität Genf                                  NaN  Universidad  46.199784
# Universität St. Gallen                            NaN  Universidad  47.431768
# Université de Lausanne                            NaN  Universidad  46.528964
# Universität Zürich                                NaN  Universidad  47.374782
# CLC Centre for Languages and Communication (ZHAW) NaN  Universidad  47.499921
#
#                                                           y  Total   \
# Name
# Universität Basel                                  7.582858    90.0
# Universität Bern                                   7.436919   120.0
# Université de Neuchâtel                            6.938709     NaN
# Universität Fribourg                               7.152665   111.0
# Universität Genf                                   6.142629   120.0
# Universität St. Gallen                             9.374598   398.0
# Université de Lausanne                             6.574077   302.0
# Universität Zürich                                 8.548334   124.0
# CLC Centre for Languages and Communication (ZHAW)  8.720451   142.0
#
#                                                                    geometry  \
# Name
# Universität Basel                                  POINT (7.58286 47.55823)
# Universität Bern                                   POINT (7.43692 46.95008)
# Université de Neuchâtel                            POINT (6.93871 46.99385)
# Universität Fribourg                               POINT (7.15266 46.80626)
# Universität Genf                                   POINT (6.14263 46.19978)
# Universität St. Gallen                             POINT (9.37460 47.43177)
# Université de Lausanne                             POINT (6.57408 46.52896)
# Universität Zürich                                 POINT (8.54833 47.37478)
# CLC Centre for Languages and Communication (ZHAW)  POINT (8.72045 47.49992)
#
#                                                                                                 name
# Name
# Universität Basel                                                                  Universität Basel
# Universität Bern                                                                    Universität Bern
# Université de Neuchâtel                                                      Université de Neuchâtel
# Universität Fribourg                                                            Universität Fribourg
# Universität Genf                                                                    Universität Genf
# Universität St. Gallen                                                       Universität St. Gallen
# Université de Lausanne                                                        Université de Lausanne
# Universität Zürich                                                                Universität Zürich
# CLC Centre for Languages and Communication (ZHAW)  CLC Centre for Languages and Communication (ZHAW)

# %% [markdown]
# Loading and preprocessing statistics for universities

# %%
file_stats = lang_dir / 'Karte3_Universitäten.xlsx'

df_uni_stats = pd.read_excel(file_stats, sheet_name='studierende_unis')

# renaming column names because geojson does not accept integers as column names
old_names = range(1988,2019)
new_names = [str(old_name) for old_name in old_names]
df_uni_stats = df_uni_stats.rename(columns=dict(zip(old_names, new_names)))


# setting primary key
df_uni_stats = df_uni_stats.set_index('name')

df_uni_stats.head(10)
# Out:
#                          1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# name
# Universität Basel          25    23    23    26    35    38    44    45    46
# Universität Bern           28    27    31    36    35    38    40    39    42
# Universität Fribourg       16    19    20    19    21    23    30    24    24
# Universität Genf           80    82    80    81    94    87    90    89    84
# Université de Lausanne     17    20    18    21    26    32    38    41    43
# Universität Zürich        101   100   108    96   104   105    86    67    85
# Université de Neuchâtel    21    20    26    25    35    30    34    29    41
#
#                          1997  ...  2009  2010  2011  2012  2013  2014  2015  \
# name                           ...
# Universität Basel          40  ...    18     9     7     6     5     8     5
# Universität Bern           41  ...    60    64    52    57    60    53    59
# Universität Fribourg       21  ...    73    76    70    69    68    60    57
# Universität Genf           82  ...    39    41    31    24    31    30    32
# Université de Lausanne     39  ...    21    24    22    23    24    22    17
# Universität Zürich         88  ...   119   124   112   107   109   100    83
# Université de Neuchâtel    46  ...    19    19    13    13    10    13    15
#
#                          2016  2017  2018
# name
# Universität Basel           5     4     2
# Universität Bern           45    45    40
# Universität Fribourg       60    60    53
# Universität Genf           30    32    24
# Université de Lausanne     10     8     9
# Universität Zürich         71    54    49
# Université de Neuchâtel    16    15    15
#
# [7 rows x 31 columns]

# %% [markdown]
# Combining points with statistics

# %%
gdf_unis_time_series = gdf_unis.join(df_uni_stats, how='inner', lsuffix='_left', rsuffix='_right')
gdf_unis_time_series = gdf_unis_time_series.drop(columns=['ID', 'Typ', 'x', 'y', 'Total '])

gdf_unis_time_series.head()
# Out:
#                                          geometry                     name  \
# Universität Basel        POINT (7.58286 47.55823)        Universität Basel
# Universität Bern         POINT (7.43692 46.95008)         Universität Bern
# Université de Neuchâtel  POINT (6.93871 46.99385)  Université de Neuchâtel
# Universität Fribourg     POINT (7.15266 46.80626)     Universität Fribourg
# Universität Genf         POINT (6.14263 46.19978)         Universität Genf
#
#                          1988  1989  1990  1991  1992  1993  1994  1995  ...  \
# Universität Basel          25    23    23    26    35    38    44    45  ...
# Universität Bern           28    27    31    36    35    38    40    39  ...
# Université de Neuchâtel    21    20    26    25    35    30    34    29  ...
# Universität Fribourg       16    19    20    19    21    23    30    24  ...
# Universität Genf           80    82    80    81    94    87    90    89  ...
#
#                          2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# Universität Basel          18     9     7     6     5     8     5     5     4
# Universität Bern           60    64    52    57    60    53    59    45    45
# Université de Neuchâtel    19    19    13    13    10    13    15    16    15
# Universität Fribourg       73    76    70    69    68    60    57    60    60
# Universität Genf           39    41    31    24    31    30    32    30    32
#
#                          2018
# Universität Basel           2
# Universität Bern           40
# Université de Neuchâtel    15
# Universität Fribourg       53
# Universität Genf           24
#
# [5 rows x 33 columns]

# %% [markdown]
# Exporting as geojson

# %%
save_dir = Path('mapas_universidades')
output_file = save_dir / 'preprocessed_data.geojson'

gdf_unis_time_series.to_file(output_file, driver='GeoJSON', encoding='utf-8')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_universidades_graphico"

# %% [markdown]
# Loading and preprocessing Uni Stufe data

# %%
file_stats = lang_dir / 'Karte3_Universitäten.xlsx'

df_uni_stats = pd.read_excel(file_stats, sheet_name='studierende_stufe')

# renaming column names because geojson does not accept integers as column names
old_names = range(1988,2019)
new_names = [str(old_name) for old_name in old_names]
df_uni_stats = df_uni_stats.rename(columns=dict(zip(old_names, new_names)))

print(list(df_uni_stats['type']))

dict_type_abbreviations = {
    'Total': 't',
    'Lizenziat / Diplom': 'ld',
    'Bachelor': 'b',
    'Master': 'm',
    'Doktorat': 'd',
    'Weiterbildung, Vertiefung und andere': 'wva'
}
df_uni_stats['code'] = df_uni_stats.apply(lambda x: dict_type_abbreviations[x['type']], axis=1)


df_uni_stats.head(10)
# Out:
# ['Total', 'Lizenziat / Diplom', 'Bachelor', 'Master', 'Doktorat', 'Weiterbildung, Vertiefung und andere']
#                                    type  1988  1989  1990  1991  1992  1993  \
# 0                                 Total   288   291   306   304   350   353
# 1                    Lizenziat / Diplom   243   245   255   258   301   316
# 2                              Bachelor     0     0     0     0     0     0
# 3                                Master     0     0     0     0     0     0
# 4                              Doktorat    28    30    34    30    35    28
# 5  Weiterbildung, Vertiefung und andere    17    16    17    16    14     9
#
#    1994  1995  1996  ...  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0   362   334   365  ...   357   307   299   307   286   268   237   218
# 1   335   311   328  ...    81    54    43    35    30    14     8     5
# 2     0     0     0  ...   143   115   127   114   104   107    91    66
# 3     0     0     0  ...    70    80    80   101    89    85    74    90
# 4    23    19    27  ...    58    49    42    54    54    54    57    55
# 5     4     4    10  ...     5     9     7     3     9     8     7     2
#
#    2018  code
# 0   192     t
# 1    12    ld
# 2    50     b
# 3    72     m
# 4    50     d
# 5     8   wva
#
# [6 rows x 33 columns]

# %% [markdown]
# Exporting as json

# %%
save_dir = Path('mapas_universidades_graphico')
output_file = save_dir / 'preprocessed_data.json'

df_uni_stats.to_json(output_file, orient='table')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_centros_de_idiomas"

# %% [markdown]
# Loading and preprocessing sprachzentren data

# %%
file_centers = lang_dir / 'SprachenzentrenUniversitäten.xlsx'
df_centers = pd.read_excel(file_centers, sheet_name='Tabelle1')
df_centers.head()
# Out:
#    ID                            Name          x         y  2009  2010  2011  \
# 0 NaN     centro de idiomas UZH y ETH  47.374604  8.548851  1182  1370  1449
# 1 NaN    centro de idiomas de la HSLU  47.046667  8.314852     0     0   218
# 2 NaN  centro de idiomas de la UniBas  47.558528  7.583869   257   269   301
# 3 NaN    centro de idiomas de la UNIL  46.523665  6.584301   402   402   420
#
#    2012  2013  2014  2015  2016  2017  2018
# 0  1559  1471  1468   935   953   939   929
# 1   251   215   199   202   204   224   188
# 2   331   356   373   483   502   425   437
# 3   484   455   483   482   449   464   401

# %%
df_centers['geometry'] = df_centers.apply(lambda x: Point(x['y'],x['x']), axis=1)

gdf_centers = gpd.GeoDataFrame(df_centers, geometry='geometry')

gdf_centers = gdf_centers.drop(columns=['ID', 'x', 'y'])
gdf_centers = gdf_centers.rename(columns={'Name': 'name'})

# renaming column names because geojson does not accept integers as column names
old_names = range(2009, 2019)
new_names = [str(old_name) for old_name in old_names]
gdf_centers = gdf_centers.rename(columns=dict(zip(old_names, new_names)))

gdf_centers.head()
# Out:
#                              name  2009  2010  2011  2012  2013  2014  2015  \
# 0     centro de idiomas UZH y ETH  1182  1370  1449  1559  1471  1468   935
# 1    centro de idiomas de la HSLU     0     0   218   251   215   199   202
# 2  centro de idiomas de la UniBas   257   269   301   331   356   373   483
# 3    centro de idiomas de la UNIL   402   402   420   484   455   483   482
#
#    2016  2017  2018                  geometry
# 0   953   939   929  POINT (8.54885 47.37460)
# 1   204   224   188  POINT (8.31485 47.04667)
# 2   502   425   437  POINT (7.58387 47.55853)
# 3   449   464   401  POINT (6.58430 46.52367)

# %% [markdown]
# Exporting as geojson

# %%
save_dir = Path('mapas_centros_de_idiomas')
output_file = save_dir / 'preprocessed_data.geojson'

gdf_centers.to_file(output_file, driver='GeoJSON', encoding='utf-8')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_academias_de_idiomas"

# %% [markdown]
# Loading and preprocessing Sprachschulen data

# %%
file_schools = lang_dir / 'Karte5_Sprachschulen_Nov.xlsx'

df_schools = pd.read_excel(file_schools, sheet_name='Tabelle1')

df_schools = df_schools.rename(columns={
    'Typ': 'type',
    'Name': 'name',
    'Adresse': 'address',
    'Webseite': 'website'
})

# setting primary key to country name
df_schools = df_schools.set_index('ID')

# converting to geodataframe
df_schools['geometry'] = df_schools.apply(lambda x: Point(x['x'],x['y']), axis=1)
gdf_schools = gpd.GeoDataFrame(df_schools, geometry='geometry')

# getting rid of unnecessary columns
gdf_schools = gdf_schools.drop(columns=['x', 'y', 'Unnamed: 7'])

df_schools.head()
# Out:
#                     type                          name          y         x  \
# ID
# #230  Escuela de idiomas  Klubschule Migros St. Gallen  47.425059  9.376588
# #231  Escuela de idiomas       Klubschule Migros Arbon  47.514926  9.430403
# #232  Escuela de idiomas       Klubschule Migros Buchs   7.164124  9.473690
# #233  Escuela de idiomas        Klubschule Migros Chur  46.852501  9.525666
# #234  Escuela de idiomas  Klubschule Migros Frauenfeld  47.556236  8.896414
#
#                                address  \
# ID
# #230    Marktgasse 17, 9000 St. Gallen
# #231       Rebenstrasse 20, 9320 Arbon
# #232       Churerstrasse 7, 9470 Buchs
# #233        Gartenstrasse 5, 7001 Chur
# #234  Rheinstrasse 10, 8500 Frauenfeld
#
#                                                 website Unnamed: 7  \
# ID
# #230  https://www.klubschule.ch/Standorte/Ostschweiz...        NaN
# #231  https://www.klubschule.ch/Standorte/Ostschweiz...        NaN
# #232  https://www.klubschule.ch/Standorte/Ostschweiz...        NaN
# #233  https://www.klubschule.ch/Standorte/Ostschweiz...        NaN
# #234  https://www.klubschule.ch/Standorte/Ostschweiz...        NaN
#
#                       geometry
# ID
# #230  POINT (9.37659 47.42506)
# #231  POINT (9.43040 47.51493)
# #232   POINT (9.47369 7.16412)
# #233  POINT (9.52567 46.85250)
# #234  POINT (8.89641 47.55624)

# %% [markdown]
# Export as geojson

# %%
save_dir = Path('mapas_academias_de_idiomas')
output_file = save_dir / 'preprocessed_data.geojson'
gdf_schools.to_file(output_file, driver='GeoJSON', encoding='utf-8')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_sedes_diplomaticas"

# %% [markdown]
# Loading embassy data and preprocessing

# %%
file_embassy = lang_dir / 'Consulados_embajadas_Dez.xlsx'
df_embassy = pd.read_excel(file_embassy)
print(df_embassy.columns)

df_embassy['geometry'] = df_embassy.apply(lambda x: Point(x['y'],x['x']), axis=1)
gdf_embassy = gpd.GeoDataFrame(df_embassy, geometry='geometry')




# renaming columns
gdf_embassy = gdf_embassy.rename(columns={
    'País': 'country',
    'Institution': 'institution',
    'Unnamed: 3': 'name',
    'Adresse': 'address',
    'Webseite': 'website'
})

gdf_embassy = gdf_embassy.drop(columns=['http://suiza.oficinascomerciales.es', 'x', 'y'])

print(gdf_embassy['country'].unique())



# used to retrieve flags from https://flag-icon-css.lip.is/
countryIDs = {
    'Argentina': 'ar',
    'Bolivia': 'bo',
    'Chile': 'cl',
    'Colombia': 'co',
    'Costa Rica': 'cr',
    'Cuba': 'cu',
    'Ecuador': 'ec',
    'El Salvador': 'sv',
    'España': 'es',
    'Guatemala': 'gt',
    'Honduras': 'hn',
    'México': 'mx',
    'Nicaragua': 'ni',
    'Panamá': 'pa',
    'Paraguay': 'py',
    'Perú': 'pe',
    'Dom. Rep.': 'do',
    'Uruguay': 'uy',
    'Venezuela': 've',
};
# adding country codes
gdf_embassy['code'] = gdf_embassy.apply(lambda row: countryIDs[row['country']], axis=1)

"""

# setting primary key
# df_embassy = df_embassy.set_index('ID')




gdf_embassy = gdf_embassy.drop(columns=['x', 'y'])

"""
gdf_embassy.head()
# Out:
# Index(['http://suiza.oficinascomerciales.es', 'Institution', 'País',
#        'Unnamed: 3', 'Adresse', 'Webseite', 'x', 'y'],
#       dtype='object')
# ['Argentina' 'Bolivia' 'Chile' 'Colombia' 'Costa Rica' 'Cuba' 'Dom. Rep.'
#  'Ecuador' 'El Salvador' 'España' 'Guatemala' 'Honduras' 'México'
#  'Nicaragua' 'Panamá' 'Paraguay' 'Perú' 'Uruguay' 'Venezuela']
#   institution    country                                               name  \
# 0   embajada   Argentina                        Embajada Argentina en Berna
# 1   consulado    Bolivia  Consulado General Estado Plurinacional de Bolivia
# 2   embajada       Chile      Embajada de Chile ante la Confederación Suiza
# 3   consulado      Chile                       Consulado de Chile en Zúrich
# 4   embajada    Colombia                      Embajada de Colombia en Suiza
#
#                                           address  \
# 0                  Jungfraustrasse 1, 3005 Berne
# 1                Rue de Lausanne 72, 1202 Genève
# 2                       Eigerplatz 5, 3007 Berne
# 3  Fuhrstrasse 12, Unterer Leihof, 8820 Wädenswil
# 4                  Zieglerstrasse 29, 3007 Berne
#
#                                              website  \
# 0                    http://www.esuiz.mrecic.gob.ar
# 1               http://www.consuladoboliviasuiza.com
# 2                     https://chile.gob.cl/suiza/en/
# 3  https://www.embassypages.com/chile-consulado-z...
# 4                       http://suiza.embajada.gov.co
#
#                    geometry code
# 0  POINT (7.45470 46.94399)   ar
# 1  POINT (6.14749 46.21572)   bo
# 2  POINT (7.43163 46.94096)   cl
# 3  POINT (8.66930 47.22584)   cl
# 4  POINT (7.42996 46.94501)   co

# %% [markdown]
# Saving embassy to geojson

# %%
save_dir = Path('mapas_sedes_diplomaticas')
output_file = save_dir / 'preprocessed_data.geojson'

gdf_embassy.to_file(output_file, driver='GeoJSON', encoding='utf-8')
reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_institutos_o_escuelas_secundarias"

# %% [markdown]
# Loading Kantis data and preprocessing

# %%
file_kantis = lang_dir / 'Karte7_Kantis_Total.xlsx'
df_kantis = pd.read_excel(file_kantis, sheet_name='Tabelle1')

df_kantis['geometry'] = df_kantis.apply(lambda x: Point(x['y'],x['x']), axis=1)

gdf_kantis = gpd.GeoDataFrame(df_kantis, geometry='geometry')


# renaming columns
gdf_kantis = gdf_kantis.rename(columns={
    'Name': 'name',
    'Adresse': 'address'
})


gdf_kantis = gdf_kantis[['name', 'address', 'geometry']]

print(gdf_kantis.shape)
gdf_kantis.head()
# Out:
# (108, 3)
#                                        name  \
# 0  Academia Engiadina Samedan Mittelschule
# 1                  Alte Kantonsschule Aarau
# 2                   Bündner Kantonsschule
# 3                          Collège Calvin
# 4                      Collège Claparède
#
#                                       address                  geometry
# 0                Quadratscha 18, 7503 Samedan  POINT (6.65844 46.50657)
# 1               Bahnhofstrasse 91, 5001 Aarau  POINT (8.05317 47.39355)
# 2                   Arosastrasse 2, 7000 Chur  POINT (9.53632 46.84853)
# 3       Rue Théodore De-Bèze 2-4, 1206 Genève  POINT (6.15207 46.20045)
# 4  Chemin de Fossard 61, 1231 Chêne-Bougeries  POINT (6.18495 46.18937)

# %% [markdown]
# Loading and preprocessing canton borders

# %%
file_cantons = gis_dir / 'boundaries_swiss_cantons.shp'
gdf_cantons = gpd.read_file(file_cantons)
print(gdf_cantons.columns)
gdf_cantons = gdf_cantons[['NAME', 'KT_TEIL', 'EINWOHNERZ', 'geometry']]
gdf_cantons = gdf_cantons.rename(columns={'NAME': 'name'})

gdf_cantons['geometry']


# remapping names
def remap_names(row):
    dict_remap_names = {
        'Graubï¿½nden': 'Graubünden',
        'Zï¿½rich': 'Zürich',
        'Genï¿½ve': 'Genève',
        'Neuchï¿½tel': 'Neuchâtel',
    }    
    old_name = row['name']
    new_name = dict_remap_names.get(old_name,False)
    if not new_name:
        return old_name
    else:
        return new_name    
gdf_cantons['name'] = gdf_cantons.apply(remap_names, axis=1)

gdf_cantons.head()
# Out:
# Index(['UUID', 'DATUM_AEND', 'DATUM_ERST', 'ERSTELL_J', 'ERSTELL_M',
#        'REVISION_J', 'REVISION_M', 'GRUND_AEND', 'HERKUNFT', 'HERKUNFT_J',
#        'HERKUNFT_M', 'OBJEKTART', 'REVISION_Q', 'ICC', 'KANTONSNUM',
#        'SEE_FLAECH', 'KANTONSFLA', 'KT_TEIL', 'NAME', 'EINWOHNERZ',
#        'geometry'],
#       dtype='object')
#          name KT_TEIL  EINWOHNERZ  \
# 0  Graubünden       0    197888.0
# 1        Bern       1   1031126.0
# 2      Valais       0    341463.0
# 3        Vaud       1    793129.0
# 4      Ticino       0    353709.0
#
#                                             geometry
# 0  POLYGON Z ((8.87705 46.81291 3062.87625, 8.877...
# 1  POLYGON Z ((7.15352 46.98628 433.29750, 7.1524...
# 2  POLYGON Z ((8.47763 46.52762 3024.43500, 8.477...
# 3  POLYGON Z ((6.77983 46.85296 429.24750, 6.7688...
# 4  POLYGON Z ((8.47763 46.52762 3024.43500, 8.477...

# %% [markdown]
# Assigning canton to each kanti

# %%
list_names = list(gdf_cantons['name'])
list_boundaries = list(gdf_cantons['geometry'])

def in_canton(row):
    point = Point(row['geometry'])
    for name, boundary in zip(list_names, list_boundaries):
        if point.within(boundary):
            return name
    return 'not found'

gdf_kantis['canton'] = gdf_kantis.apply(in_canton, axis=1)

gdf_kantis.head()
# Out:
#                                        name  \
# 0  Academia Engiadina Samedan Mittelschule
# 1                  Alte Kantonsschule Aarau
# 2                   Bündner Kantonsschule
# 3                          Collège Calvin
# 4                      Collège Claparède
#
#                                       address                  geometry  \
# 0                Quadratscha 18, 7503 Samedan  POINT (6.65844 46.50657)
# 1               Bahnhofstrasse 91, 5001 Aarau  POINT (8.05317 47.39355)
# 2                   Arosastrasse 2, 7000 Chur  POINT (9.53632 46.84853)
# 3       Rue Théodore De-Bèze 2-4, 1206 Genève  POINT (6.15207 46.20045)
# 4  Chemin de Fossard 61, 1231 Chêne-Bougeries  POINT (6.18495 46.18937)
#
#        canton
# 0        Vaud
# 1      Aargau
# 2  Graubünden
# 3      Genève
# 4      Genève

# %% [markdown]
# Export kantis data as geojson

# %%
save_dir = Path('mapas_institutos_o_escuelas_secundarias')

absolute_file = save_dir / 'preprocessed_data_absolute.geojson'
# df_cantons.to_json(absolute_file, orient='records', encoding='utf-8')
gdf_cantons.to_file(absolute_file, driver='GeoJSON', encoding='utf-8')
reformat_json(absolute_file)

kantis_file = save_dir / 'preprocessed_data_kantis.geojson'
gdf_kantis.to_file(kantis_file, driver='GeoJSON', encoding='utf-8')
# reformat_json(kantis_file)

# %% [markdown]
# Get number of kantis for each canton

# %%
gdf_kantis['count'] = 1
dict_n_kantis = gdf_kantis.groupby(['canton']).sum()['count'].to_dict()
# print(dict_n_kantis)
def n_kantis(row):
    return dict_n_kantis.get(row['name'], 0)
gdf_cantons['n_kantis'] = gdf_cantons.apply(n_kantis, axis=1, result_type='expand')


dict_n_inhabitants = gdf_cantons.groupby(['name'])['EINWOHNERZ'].sum().to_dict()
# print(dict_n_inhabitants)
gdf_cantons['n_inhabitants'] = gdf_cantons.apply(lambda row: dict_n_inhabitants[row['name']], axis=1)

gdf_cantons = gdf_cantons.drop(columns=['EINWOHNERZ'])
gdf_cantons = gdf_cantons.rename(columns={'KT_TEIL': 'part'})


gdf_cantons.head()
# Out:
#          name part                                           geometry  \
# 0  Graubünden    0  POLYGON Z ((8.87705 46.81291 3062.87625, 8.877...
# 1        Bern    1  POLYGON Z ((7.15352 46.98628 433.29750, 7.1524...
# 2      Valais    0  POLYGON Z ((8.47763 46.52762 3024.43500, 8.477...
# 3        Vaud    1  POLYGON Z ((6.77983 46.85296 429.24750, 6.7688...
# 4      Ticino    0  POLYGON Z ((8.47763 46.52762 3024.43500, 8.477...
#
#    n_kantis  n_inhabitants
# 0         4       197888.0
# 1         9      1031126.0
# 2         0       341463.0
# 3        13       793129.0
# 4         5       353709.0

# %% [markdown]
# Export data for choropleth map (kantis per inhabitants)

# %%
gdf_cantons_choropleth = gpd.GeoDataFrame(gdf_cantons, geometry='geometry')

choropleth_file = save_dir / 'preprocessed_data_choropleth.geojson'
gdf_cantons_choropleth.to_file(choropleth_file, driver='GeoJSON', encoding='utf-8')

# %% [markdown]
# Subset cantons such that there is only 1 entry (polygon) per canton.
# In case of multiple polygons, the largest one is used.

# %%
gdf_cantons = gdf_cantons[(gdf_cantons['KT_TEIL'] == '0') | (gdf_cantons['KT_TEIL'] == '1')]

print(gdf_cantons.shape)
gdf_cantons.head(26)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\mapa\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KT_TEIL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-b1add72decac> in <module>
# ----> 1 gdf_cantons = gdf_cantons[(gdf_cantons['KT_TEIL'] == '0') | (gdf_cantons['KT_TEIL'] == '1')]
#       2
#       3 print(gdf_cantons.shape)
#       4 gdf_cantons.head(26)
#
# ~\AppData\Local\Continuum\anaconda3\envs\mapa\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     544         GeoDataFrame.
#     545         """
# --> 546         result = super(GeoDataFrame, self).__getitem__(key)
#     547         geo_col = self._geometry_column_name
#     548         if isinstance(key, string_types) and key == geo_col:
#
# ~\AppData\Local\Continuum\anaconda3\envs\mapa\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\envs\mapa\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KT_TEIL'

# %% [markdown]
# Compute centroid for each polygon (centroid will correspond to the marker position on the map)

# %%
# adding centroid
gdf_cantons['geometry'] = gdf_cantons.apply(lambda x: Polygon(x['geometry']).centroid, axis=1)

# %%
gdf_cantons['x'] = gdf_cantons.apply(lambda row: row['geometry'].x, axis=1)
gdf_cantons['y'] = gdf_cantons.apply(lambda row: row['geometry'].y, axis=1)
gdf_cantons.head()
# Out:
#          name KT_TEIL  EINWOHNERZ  \
# 0  Graubünden       0    197888.0
# 1        Bern       1   1031126.0
# 2      Valais       0    341463.0
# 3        Vaud       1    793129.0
# 4      Ticino       0    353709.0
#
#                                       geometry  n_kantis         x          y
# 0   POINT (9.62862381268349 46.65606579160512)         4  9.628624  46.656066
# 1  POINT (7.624744294648847 46.82208787558518)         9  7.624744  46.822088
# 2  POINT (7.605940034344669 46.20935513994819)         0  7.605940  46.209355
# 3  POINT (6.646681769033475 46.55944971911612)        13  6.646682  46.559450
# 4  POINT (8.808554728958551 46.29606041574468)         5  8.808555  46.296060

# %% [markdown]
# Exporting as geojson

# %%
gdf_cantons = gdf_cantons.drop(columns=['KT_TEIL', 'EINWOHNERZ', 'geometry'])
df_cantons = pd.DataFrame(gdf_cantons)
df_cantons.to_json(f'../map7/map7_absolute.json', orient='records', encoding='utf-8')

# gdf_cantons = gpd.GeoDataFrame(gdf_cantons, geometry='geometry')
# gdf_cantons.to_file(f'../map7/map7_absolut.geojson', driver='GeoJSON', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-254a3f3e8f9b> in <module>
#       1 gdf_cantons = gdf_cantons.drop(columns=['KT_TEIL', 'EINWOHNERZ', 'geometry'])
#       2 df_cantons = pd.DataFrame(gdf_cantons)
# ----> 3 df_cantons.to_json(f'../map7/map7_absolute.json', orient='records', encoding='utf-8')
#       4
#       5 # gdf_cantons = gpd.GeoDataFrame(gdf_cantons, geometry='geometry')
#
# TypeError: to_json() got an unexpected keyword argument 'encoding'

# %% [markdown]
# # Preprocessing "mapas_centros_y_asociaciones_educativas"

# %% [markdown]
# Loading all language data (Bildung, Sprachschulen and Botschaften) and adding adding geometry columns

# %%
file_master = lang_dir / 'Karte7_Bildung_Dez.xlsx'
df_bildung = pd.read_excel(file_master, sheet_name='Tabelle1')

print(df_bildung.columns)

df_bildung['geometry'] = df_bildung.apply(lambda x: Point(x['y'],x['x']), axis=1)
gdf_bildung = gpd.GeoDataFrame(df_bildung, geometry='geometry')

gdf_bildung = gdf_bildung.drop(columns=['ID', 'x', 'y'])
gdf_bildung = gdf_bildung.rename(columns={
    'Typ': 'type',
    'Total ': 'total',
    'Name': 'name'
})

print(gdf_bildung['type'].unique())


# assign abbreviations for the different types of schools
dict_type_abbreviations = {
    'ALCE': 'ALCE',
    'Centro de idiomas ': 'CDI',
    'DELE': 'DELE',
    'Enseñanza primaria ': 'EP',
    'Instituto de ensenãnza media': 'IDEM',
    'Universidad': 'U'
}
gdf_bildung['type_abbr'] = gdf_bildung.apply(lambda x: dict_type_abbreviations[x['type']], axis=1)

print(gdf_bildung.shape)
print(gdf_bildung['type'].unique())
gdf_bildung.head()
# Out:
# Index(['ID', 'Typ', 'x', 'y', 'Total ', 'Name'], dtype='object')
# ['ALCE' 'Centro de idiomas ' 'DELE' 'Enseñanza primaria '
#  'Instituto de ensenãnza media' 'Universidad']
# (222, 5)
# ['ALCE' 'Centro de idiomas ' 'DELE' 'Enseñanza primaria '
#  'Instituto de ensenãnza media' 'Universidad']
#    type  total  name                  geometry type_abbr
# 0  ALCE     30  ALCE  POINT (8.04570 47.39043)      ALCE
# 1  ALCE     38  ALCE  POINT (7.60051 47.47449)      ALCE
# 2  ALCE     71  ALCE  POINT (8.30982 47.47137)      ALCE
# 3  ALCE     66  ALCE  POINT (7.60546 47.56364)      ALCE
# 4  ALCE     67  ALCE  POINT (7.58897 47.56993)      ALCE

# %% [markdown]
# Saving as geojson

# %%
save_dir = Path('mapas_centros_y_asociaciones_educativas')
output_file = save_dir / 'preprocessed_data.geojson'
gdf_bildung.to_file(output_file, driver='GeoJSON', encoding='utf-8')
# reformat_json(output_file)

# %% [markdown]
# # Preprocessing "mapas_espacios_culturales_y_sociales"

# %% [markdown]
# Loading and preprocessing cultural data

# %%
file_culture = lang_dir / 'Karte6_VereineKulturzentren.xlsx'
df_culture = pd.read_excel(file_culture, sheet_name='asociaciones')


df_culture = df_culture.rename(columns={
    'Typ': 'type',
    'Vereinsname': 'name',
    'Adresse': 'address',
    'Kontakt': 'contact'
})

df_culture['ID'] = df_culture['ID'].astype(str)

# setting primary key
df_culture = df_culture.set_index('ID')

df_culture['geometry'] = df_culture.apply(lambda x: Point(x['y'],x['x']), axis=1)
gdf_culture = gpd.GeoDataFrame(df_culture, geometry='geometry')

gdf_culture = gdf_culture.drop(columns=['x', 'y'])

gdf_culture.head()
# Out:
#             type                                               name  \
# ID
# #901  asociación  "Silberbär" Asociación de Mayores y Jubilados ...
# #902  asociación  “Arco Iris” Asociación de Pensionistas del Ámb...
# #903  asociación                       Asistencia Social en Español
# #904  asociación                          Asociación “Arte Andaluz”
# #905  asociación                             Asociación “Esperanza”
#
#                                               address  \
# ID
# #901           Muristrasse 12, Postfach, 3000 Bern 31
# #902                  Missionsstrasse 34 – 4055 Basel
# #903              Bahnhofplatz 1, 3° Piso, 5400 Baden
# #904        Chemin de Maisonneuve 10, 1219 Châtelaine
# #905  Komotar Cavezuelo, Brüderhofweg 15, 8050 Zürich
#
#                                     contact                  geometry
# ID
# #901              mayores.berna@hotmail.com  POINT (7.46057 46.94430)
# #902                  info@arcoirisbasel.ch  POINT (7.57741 47.56018)
# #903  e-mail: carmen.palmeiro@kathaargau.ch  POINT (8.30846 47.47610)
# #904        e-mail : arteandaluz@bluewin.ch  POINT (6.11269 46.21207)
# #905           e-mail: esperanza@bluewin.ch  POINT (8.53915 47.39940)

# %% [markdown]
# Save as geojson

# %%
save_dir = Path('mapas_espacios_culturales_y_sociales')
output_file = save_dir / 'preprocessed_data.geojson'
gdf_culture.to_file(output_file, driver='GeoJSON', encoding='utf-8')
